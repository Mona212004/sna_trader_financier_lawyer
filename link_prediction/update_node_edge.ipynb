# %%
import pandas as pd
import networkx as nx
from matplotlib import pyplot as plt
import numpy as np

# %%
edge_list = pd.read_csv(r"D:\commo\code\4_kumu_struct\edge_list.csv")
node1 = pd.read_csv(r"D:\commo\code\4_kumu_struct\node_list1.csv")
node2 = pd.read_csv(r"D:\commo\code\4_kumu_struct\node_list2.csv")
node3 = pd.read_csv(r"D:\commo\code\4_kumu_struct\node_list3.csv")
others = pd.read_csv(r"D:\commo\code\4_kumu_struct\others.csv")

# %%
edge_list["To"] = edge_list["To"].str.replace(r"[()]", "", regex=True)
edge_list.loc[edge_list['To'] == 'mitsui & co energy trading singapore ', 'To'] = 'mitsui & co energy trading singapore mets'

## replaced Unknown with n/a
node1 = node1.apply(lambda col: col.mask(col.astype(str).str.strip().str.lower() == 'unknown', np.nan) if col.dtype == 'object' else col)
node2 = node2.apply(lambda col: col.mask(col.astype(str).str.strip().str.lower() == 'unknown', np.nan) if col.dtype == 'object' else col)
node3 = node3.apply(lambda col: col.mask(col.astype(str).str.strip().str.lower() == 'unknown', np.nan) if col.dtype == 'object' else col)
edge_list = edge_list.apply(lambda col: col.mask(col.astype(str).str.strip().str.lower() == 'unknown', np.nan) if col.dtype == 'object' else col)

# %%
node1.rename(columns={
    'Label':'label',
    'Type':'role',
    'Description':'description',
    'Tier':'tier',
    'Commodity Type':'commodity_type',
    'Commodity Focus':'commodity_focus',
    'Legal Name / ACRA UEN':'acra_uen',
    'HQ Country':'hq_country',
    'Estimated Revenue':'est_revenue',
    'Headcount (Global)':'global_headcount',
    'Trade Volume (Est.)':'est_trade_volume',
    'Ownership Structure':"ownership_struct",
    'Exchange':'exchange',
    'APAC offices':'sg_address'
}, inplace=True)
node2.rename(columns={
    'Label':'label',
    'Type':'role',
    'Description':'description',
    'Scope':'scope',
    'Office Location(s) in APAC':'sg_address',
    'Practice Areas':'practice_areas',
    'Known Client Base':'known_clients'
}, inplace=True)
node3.rename(columns={
    'Label':'label',
    'Type':'role',
    'Description':'description',
    'Financier Type':'financier_type',
    'Commodity Type':'commodity_type',
    'Geographic Reach':'geographic_reach',
    'Known Clients':'known_clients'
}, inplace=True)

# %%
new_node1 = pd.DataFrame(columns=['label','role', 'description', 'tier', 'commodity_type','commodity_focus', 'acra_uen', 'hq_country', 'est_revenue','global_headcount', 'est_trade_volume', 'ownership_struct', 'exchange', 'sg_address'])
new_node1['label'] = [
            "alvari",
            "avani resources",
            "basf intertrade ag singapore branch",
            "bgn energy",
            "equatorial marine fuel management services",
            "gp global apac",
            "halcyon agri corporation",
            "jsw international tradecorp jsw",
            "lex oil",
            "olam food ingredients",
            "royal global exports",
            "sinar mas group",
            "six one commodities",
            "sumifru singapore",
            "the prax group",
            "uganda national oil unoc",
            "uniper global commodities se singapore branch",
            "winson oil trading", 'bunge', 'cargill', 'cofco international', 'glencore', 'gunvor group', 'louis dreyfus company', 'mercuria', 'mercuria energy group', 'mercuria energy trading', 'mitsui & co energy trading singapore mets', 'petrochina international singapore', 'sinopec', 'sinopec international singapore', 'vitol group'
        ]
new_node1["role"] = "trader"
new_node1.loc[new_node1["label"] == "alvari", "tier"] = 1
new_node1.loc[new_node1["label"] == "avani resources", "tier"] = 1
new_node1.loc[new_node1["label"] == "basf intertrade ag singapore branch", "tier"] = 2
new_node1.loc[new_node1["label"] == "equatorial marine fuel management services", "tier"] = 2
new_node1.loc[new_node1["label"] == "gp global apac", "tier"] = 1
new_node1.loc[new_node1["label"] == "halcyon agri corporation", "tier"] = 1
new_node1.loc[new_node1["label"] == "olam food ingredients", "tier"] = 1
new_node1.loc[new_node1["label"] == "sinar mas group", "tier"] = 1
new_node1.loc[new_node1["label"] == "six one commodities", "tier"] = 2
new_node1.loc[new_node1["label"] == "the prax group", "tier"] = 1
new_node1.loc[new_node1["label"] == "uniper global commodities se singapore branch", "tier"] = 1
new_node1.loc[new_node1["label"] == "winson oil trading", "tier"] = 1
new_node1.loc[new_node1["label"] == "alvari", "commodity_type"] = "energy"
new_node1.loc[new_node1["label"] == "avani resources", "commodity_type"] = "multi (>2 types)"
new_node1.loc[new_node1["label"] == "basf intertrade ag singapore branch", "commodity_type"] = "petrochemicals"
new_node1.loc[new_node1["label"] == "bgn energy", "commodity_type"] = "energy"
new_node1.loc[new_node1["label"] == "equatorial marine fuel management services", "commodity_type"] = "energy"
new_node1.loc[new_node1["label"] == "gp global apac", "commodity_type"] = "energy"
new_node1.loc[new_node1["label"] == "halcyon agri corporation", "commodity_type"] = "soft/agricultural"
new_node1.loc[new_node1["label"] == "jsw international tradecorp jsw", "commodity_type"] = "hard/metals"
new_node1.loc[new_node1["label"] == "lex oil", "commodity_type"] = "energy"
new_node1.loc[new_node1["label"] == "sinar mas group", "commodity_type"] = "multi (>2 types)"
new_node1.loc[new_node1["label"] == "six one commodities", "commodity_type"] = "multi (>2 types)"
new_node1.loc[new_node1["label"] == "sumifru singapore", "commodity_type"] = "soft/agricultural"
new_node1.loc[new_node1["label"] == "the prax group", "commodity_type"] = "multi (>2 types)"
new_node1.loc[new_node1["label"] == "uganda national oil unoc", "commodity_type"] = "energy"
new_node1.loc[new_node1["label"] == "uniper global commodities se singapore branch", "commodity_type"] = "energy"
new_node1.loc[new_node1["label"] == "winson oil trading", "commodity_type"] = "energy"
new_node1.loc[new_node1["label"] == "avani resources", "hq_country"] = "Singapore"
new_node1.loc[new_node1["label"] == "basf intertrade ag singapore branch", "hq_country"] = "Switzerland"
new_node1.loc[new_node1["label"] == "equatorial marine fuel management services", "hq_country"] = "Singapore"
new_node1.loc[new_node1["label"] == "gp global apac", "hq_country"] = "UAE"
new_node1.loc[new_node1["label"] == "halcyon agri corporation", "hq_country"] = "Singapore"
new_node1.loc[new_node1["label"] == "jsw international tradecorp jsw", "hq_country"] = "India"
new_node1.loc[new_node1["label"] == "olam food ingredients", "hq_country"] = "Singapore"
new_node1.loc[new_node1["label"] == "sinar mas group", "hq_country"] = "Indonesia"
new_node1.loc[new_node1["label"] == "sumifru singapore", "hq_country"] = "Japan"
new_node1.loc[new_node1["label"] == "the prax group", "hq_country"] = "UK"
new_node1.loc[new_node1["label"] == "uganda national oil unoc", "hq_country"] = "Uganda"
new_node1.loc[new_node1["label"] == "uniper global commodities se singapore branch", "hq_country"] = "Germany"
new_node1.loc[new_node1["label"] == "winson oil trading", "hq_country"] = "Singapore"
new_node1.loc[new_node1["label"] == "alvari", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "avani resources", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "basf intertrade ag singapore branch", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "bgn energy", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "equatorial marine fuel management services", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "gp global apac", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "halcyon agri corporation", "ownership_struct"] = "listed"
new_node1.loc[new_node1["label"] == "jsw international tradecorp jsw", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "lex oil", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "olam food ingredients", "ownership_struct"] = "listed"
new_node1.loc[new_node1["label"] == "royal global exports", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "sinar mas group", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "six one commodities", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "sumifru singapore", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "the prax group", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "uganda national oil unoc", "ownership_struct"] = "state-owned"
new_node1.loc[new_node1["label"] == "uniper global commodities se singapore branch", "ownership_struct"] = "state-owned"
new_node1.loc[new_node1["label"] == "winson oil trading", "ownership_struct"] = "private"
new_node1.loc[new_node1["label"] == "avani resources", "sg_address"] = "143 Cecil Street, #24-01/02 GB Building, Singapore 069542"
new_node1.loc[new_node1["label"] == "equatorial marine fuel management services", "sg_address"] = "38 Carpenter Street, #05-01, Singapore 059917"
new_node1.loc[new_node1["label"] == "halcyon agri corporation", "sg_address"] = "180 Clemenceau Avenue, #05-02 Haw Par Centre, Singapore 239922"
new_node1.loc[new_node1["label"] == "jsw international tradecorp jsw", "sg_address"] = "9 Raffles Place, #20-01 Republic Plaza, Singapore 048619"
new_node1.loc[new_node1["label"] == "sinar mas group", "sg_address"] = "108 Pasir Panjang Road, #06-00 Golden Agri Plaza, Singapore 118535"
new_node1.loc[new_node1["label"] == "winson oil trading", "sg_address"] = "3 Phillip Street, #09-01 Royal Group Building, Singapore 048693"

new_node_others = pd.DataFrame(columns=['label','role'])
new_node_others['label'] = [
    'amaroq', 'argoglobal underwriting asia pacific', 'atlantic navigation holdings singapore',
    'bafco singapore', 'barramundi group', 'boustead projects', 'bts tankers', 'bw energy holdings',
    'china merchants energy shipping holding singapore', 'china taiping insurance singapore', 'cye',
    'develop global', 'first sponsor group', 'fti consulting singapore', 'glory bulk carriers',
    'grabtaxi holdings', 'great american insurance company', 'ho lee construction', 'katanga mining',
    'kipushi corporation sa', 'kpmg', 'maersk tankers singapore', 'marina offshore', 'metro holdings',
    'ms first capital insurance', 'new & novel engineering', 'ocean network express',
    'perennial real estate holdings', 'pricewaterhousecoopers pwc singapore', 'qbe insurance singapore',
    'razer', 'rio tinto', 'seatrium', 'seraya energy', 'st telemedia global data centres',
    'tai chong cheang shipping singapore', 'tarago operations', 'the daily cut',
    'the singapore medical council smc', 'thomson medical group tmg', 'trafigura beheer bv',
    'trafigura maritime logistics', 'vale', 'vast resources', 'westbridge ventures ii investment holdings',
    'woodlawn mine holdings', 'gtp advisory pac', 'vyas engineering'
]
new_node_others["role"] = 'others'

new_node3 = pd.DataFrame(columns=['label', 'role', 'description', 'financier_type', 'commodity_type', 'geographic_reach', 'known_clients'])
new_node3['label']=['ed&f man capital markets singapore', 'hsbc singapore entities', 'icici bank singapore branch','maybank singapore', 'mizuho bank', 'standard chartered bank singapore scb']
new_node3["role"] = "lender"
new_node3.loc[new_node3["label"] == "ed&f man capital markets singapore",'financier_type'] = 'Alternative Financier'
new_node3.loc[new_node3["label"] == "hsbc singapore entities",'financier_type'] = 'Traditional Bank'
new_node3.loc[new_node3["label"] == "icici bank singapore branch",'financier_type'] = 'Traditional Bank'
new_node3.loc[new_node3["label"] == "maybank singapore",'financier_type'] = 'Traditional Bank'
new_node3.loc[new_node3["label"] == "mizuho singapore",'financier_type'] = 'Traditional Bank'
new_node3.loc[new_node3["label"] == "standard chartered bank singapore scb",'financier_type'] = 'Traditional Bank'
new_node3.loc[new_node3["label"] == "icici bank singapore branch",'commodity_type'] = 'energy'
new_node3.loc[new_node3["label"] == "maybank singapore", "commodity_type"] = "soft/agricultural"
new_node3.loc[new_node3["label"] == "mizuho singapore",'commodity_type'] = 'hard/metals'
# replace commas with |
def comma_to_tag(cell):
    if pd.isna(cell) or not isinstance(cell, str) or not cell.strip():
        return None
    return cell.replace(",", " |")
new_node3["commodity_type"] = new_node3["commodity_type"].apply(comma_to_tag)

#'From', 'To', 'Direction', 'Type'
new_edges = pd.DataFrame(columns=["From", "To", "Direction", "Type"])
new_edges = pd.DataFrame(
    data=[{"From": "ed&f man capital", "To": "ed&f man capital markets singapore", 'Direction':'directed', 'Type':'owns'},
          {"From": "hsbc", "To": "hsbc singapore entities", 'Direction':'directed', 'Type':'owns'},
          {"From": "standard chartered", "To": "standard chartered bank singapore scb", 'Direction':'directed', 'Type':'owns'}]
)

node1 = pd.concat([node1, new_node1], ignore_index=True)
node3 = pd.concat([node3, new_node3], ignore_index=True)
edge_list = pd.concat([edge_list, new_edges], ignore_index=True)

node1.drop_duplicates(inplace=True)
node2.drop_duplicates(inplace=True)
node3.drop_duplicates(inplace=True)
new_node_others.drop_duplicates(inplace=True)
edge_list.drop_duplicates(inplace=True)

all_documented_labels = set(node1['label']) | set(node2['label']) | set(node3['label']) | set(others['label'])
edge_labels = set(edge_list['From']) | set(edge_list['To'])

undocumented = edge_labels - all_documented_labels
print(len(undocumented), "undocumented entities out of", len(edge_labels), "total in edge_list")
print(sorted(undocumented))
# Out:
# 0 undocumented entities out of 163 total in edge_list
# []

# %%
edge_list.duplicated().sum()
# Out:
# np.int64(0)

# %%
node1.to_csv(r"D:\commo\code\4_kumu_struct\node_list1.csv", index=False)
node2.to_csv(r"D:\commo\code\4_kumu_struct\node_list2.csv", index=False)
node3.to_csv(r"D:\commo\code\4_kumu_struct\node_list3.csv", index=False)
edge_list.to_csv(r"D:\commo\code\4_kumu_struct\edge_list.csv", index=False)
new_node_others.to_csv(r"D:\commo\code\4_kumu_struct\others.csv", index=False)
